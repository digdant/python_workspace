# %%
import pandas as pd
import numpy as np

import tensorflow as tf

# %% [markdown]
# # Carregando e Preparando o Dataset

# %%
df = pd.read_csv('/content/Iris.csv')

#df_titanic = pd.read_csv('/content/train.csv')

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df = df.drop(columns=['Id'])

# %%
#data = pd.get_dummies(df, columns = ['Species'])

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['Species'] = df['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})

# %%
from sklearn.model_selection import train_test_split


X = df.drop(columns=['Species'])
y = df['Species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((105, 4), (45, 4), (105,), (45,))

# %% [markdown]
# # Padronizando os Dados

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Rede Neural - Treino

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, input_shape=(4,), activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics='accuracy')

# %%
BATCH_SIZE = 4
EPOCHS = 20

# %%
model.fit(X_train, y_train, batch_size = BATCH_SIZE, epochs=EPOCHS)
# Out:
# Epoch 1/20
# 27/27 [==============================] - 1s 2ms/step - loss: 0.8576 - accuracy: 0.6381
# Epoch 2/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6086 - accuracy: 0.8000
# Epoch 3/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4861 - accuracy: 0.8286
# Epoch 4/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4116 - accuracy: 0.8286
# Epoch 5/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3676 - accuracy: 0.8381
# Epoch 6/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3314 - accuracy: 0.8571
# Epoch 7/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3054 - accuracy: 0.8571
# Epoch 8/20
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2782 - accuracy: 0.8857
# Epoch 9/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2566 - accuracy: 0.9238
# Epoch 10/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2347 - accuracy: 0.9238
# Epoch 11/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2134 - accuracy: 0.9429
# Epoch 12/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1970 - accuracy: 0.9429
# Epoch 13/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1741 - accuracy: 0.9429
# Epoch 14/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1593 - accuracy: 0.9429
# Epoch 15/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1482 - accuracy: 0.9333
# Epoch 16/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1333 - accuracy: 0.9429
# Epoch 17/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1241 - accuracy: 0.9429
# Epoch 18/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1157 - accuracy: 0.9619
# Epoch 19/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1145 - accuracy: 0.9429
# Epoch 20/20
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1008 - accuracy: 0.9619

# %%
model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0525 - accuracy: 1.0000
# [0.05247177928686142, 1.0]

# %%
y_pred = model.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 7ms/step

# %%
y_pred = [np.argmax(v) for v in y_pred]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
