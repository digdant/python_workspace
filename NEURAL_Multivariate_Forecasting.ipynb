# %%
# !pip install tf_agents

# !pip install tensorflow==2.9

# %%
# !pip install tensorflow==2.15

# %%
from sklearn.metrics import mean_squared_error as mse

def plot_predictions1(model, X, y, start=0, end=100):
  predictions = model.predict(X).flatten()
  df = pd.DataFrame(data={'Predictions':predictions, 'Actuals':y})
  plt.plot(df['Predictions'][start:end])
  plt.plot(df['Actuals'][start:end])
  return df, mse(y, predictions)

# %%
import pandas as pd

df = pd.read_csv('/content/prepared_2.csv')

# %%
y = df['target']
df = df.drop(columns=['target'])

# %%
categorical = df.select_dtypes(include=['object']).columns.tolist()

# %%
categorical
# Out:
# ['P_2n_7_str',
#  'balanceamento_p_2n_7_str',
#  'soma_mediana_maior_geral_str',
#  'faixa_soma_5_layers_str']

# %%
df = pd.get_dummies(df, columns = categorical)

# %%
df['target'] = y

# %%
numerical = df.select_dtypes(include=['number']).columns.tolist()

# %%
df.columns
# Out:
# Index(['ATUAL_soma', 'dz3_dz4_dist_fileiras_int', 'dz2_dz5_dist_fileiras_int',
#        'maior_qtde_sorteados_fileira_int', 'fileira_maior_qtde_sorteado_int',
#        'maior_qtde_sorteados_ocorrencias_int',
#        'dist_entre_fileiras_com_zero_int', 'qtde_fileiras_sorteadas',
#        'P_2n_7_str_bin_A_1_a_30_1x_e_bin_B_31_a_60_5x',
#        'P_2n_7_str_bin_A_1_a_30_2x_e_bin_B_31_a_60_4x',
#        'P_2n_7_str_bin_A_1_a_30_3x_e_bin_B_31_a_60_3x',
#        'P_2n_7_str_bin_A_1_a_30_4x_e_bin_B_31_a_60_2x',
#        'P_2n_7_str_bin_A_1_a_30_5x_e_bin_B_31_a_60_1x',
#        'P_2n_7_str_bin_A_1_a_30_6x', 'P_2n_7_str_bin_B_31_a_60_6x',
#        'balanceamento_p_2n_7_str_desbalanceado_para_o_Final',
#        'balanceamento_p_2n_7_str_desbalanceado_para_o_Inicio',
#        'balanceamento_p_2n_7_str_equilibrado_3x_3x',
#        'soma_mediana_maior_geral_str_NAO', 'soma_mediana_maior_geral_str_SIM',
#        'faixa_soma_5_layers_str_soma_alta',
#        'faixa_soma_5_layers_str_soma_baixa',
# ...

# %%
df.dtypes
# Out:
# ATUAL_soma                                               int64
# dz3_dz4_dist_fileiras_int                                int64
# dz2_dz5_dist_fileiras_int                                int64
# maior_qtde_sorteados_fileira_int                         int64
# fileira_maior_qtde_sorteado_int                          int64
# maior_qtde_sorteados_ocorrencias_int                     int64
# dist_entre_fileiras_com_zero_int                         int64
# qtde_fileiras_sorteadas                                  int64
# P_2n_7_str_bin_A_1_a_30_1x_e_bin_B_31_a_60_5x            uint8
# P_2n_7_str_bin_A_1_a_30_2x_e_bin_B_31_a_60_4x            uint8
# P_2n_7_str_bin_A_1_a_30_3x_e_bin_B_31_a_60_3x            uint8
# P_2n_7_str_bin_A_1_a_30_4x_e_bin_B_31_a_60_2x            uint8
# P_2n_7_str_bin_A_1_a_30_5x_e_bin_B_31_a_60_1x            uint8
# P_2n_7_str_bin_A_1_a_30_6x                               uint8
# P_2n_7_str_bin_B_31_a_60_6x                              uint8
# ...

# %%
df['target'] = y

# %%
df
# Out:
#       ATUAL_soma  dz3_dz4_dist_fileiras_int  dz2_dz5_dist_fileiras_int  \
# 0            163                          0                          2
# 1            140                          2                          4
# 2             90                          1                          1
# 3            148                          1                          2
# 4            143                          1                          3
# ...          ...                        ...                        ...
# 2661         166                          1                          2
# 2662         136                          0                          2
# 2663         179                          0                          2
# 2664         131                          2                          4
# 2665         202                          2                          2
#
#       maior_qtde_sorteados_fileira_int  fileira_maior_qtde_sorteado_int  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

df['target'] = encoder.fit_transform(df[['target']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df
# Out:
#       ATUAL_soma  dz3_dz4_dist_fileiras_int  dz2_dz5_dist_fileiras_int  \
# 0            163                          0                          2
# 1            140                          2                          4
# 2             90                          1                          1
# 3            148                          1                          2
# 4            143                          1                          3
# ...          ...                        ...                        ...
# 2661         166                          1                          2
# 2662         136                          0                          2
# 2663         179                          0                          2
# 2664         131                          2                          4
# 2665         202                          2                          2
#
#       maior_qtde_sorteados_fileira_int  fileira_maior_qtde_sorteado_int  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
y = df['target']
X = df.drop(columns=['target'])

# %%
y
# Out:
# 0       235
# 1       350
# 2       368
# 3       254
# 4       320
#        ...
# 2661    145
# 2662    236
# 2663    200
# 2664    350
# 2665    190
# Name: target, Length: 2666, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

from sklearn.preprocessing import StandardScaler


scaler = StandardScaler()

scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1866, 25), (800, 25), (1866,), (800,))

# %% [markdown]
# # LSTM

# %%
# Assuming you have X_train, y_train, X_test as your input features and targets

# Step 2: Train Random Forest Classifier
# View accuracy score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier

rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train, y_train)

# Step 3: Generate Predictions
rf_predictions = rf_classifier.predict(X_test)

accuracy_score(y_test, rf_predictions)

# Step 4: Data Transformation for LSTM
X_lstm = np.concatenate((X_test, rf_predictions.reshape(-1, 1)), axis=1)

# Assuming feedback states: 0 for "negative," 1 for "partially correct," 2 for "positive"
feedback_states = np.random.randint(0, 3, size=(X_lstm.shape[0], 1))

# Combine feedback states with LSTM features
X_combined = np.concatenate((X_lstm, feedback_states), axis=1)

# %%
# Assuming label-encoded targets
num_classes = len(np.unique(y_train))

# %%
num_classes
# Out:
# 353

# %%
# Step 5: Build and Train LSTM Model
# ... define and compile LSTM model using a library like TensorFlow/Keras

# Assuming you have X_train, y_train, X_test, and feedback_states as before
# Assuming you have an RL environment, define it using tf_py_environment
# Assuming you have an RL agent, define it

win_length = 168
batch_size = 32
num_features = X_lstm.shape[1] + 2 # 26
# Define the LSTM model using Keras with linear activation in the output layer
lstm_model = tf.keras.Sequential([
    tf.keras.layers.LSTM(64, input_shape=(batch_size,, num_features)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(num_classes, activation='softmax')  # Use softmax for multi-class classification
])

# Compile the model using categorical crossentropy as the loss function
lstm_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
lstm_model.fit(X_train, y_train)

# %%
lstm_predictions = lstm_model.predict(X_test)

# %% [markdown]
# # REDE NEURAL NORMAL

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, input_shape=(len(X_train),), activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics='accuracy')

# %%
BATCH_SIZE = 30
EPOCHS = 200

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
model.fit(X_train, y_train.to_numpy(), batch_size = BATCH_SIZE, epochs=EPOCHS)
# Out:
# Epoch 1/200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-250-35ad2aab5a1b> in <cell line: 1>()
# ----> 1 model.fit(X_train, y_train.to_numpy(), batch_size = BATCH_SIZE, epochs=EPOCHS)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ...

# %%
model.evaluate(X_test, y_test)

# %%
y_pred = model.predict(X_test)
# Out:
# 25/25 [==============================] - 0s 1ms/step

# %%
import numpy as np
y_pred = [np.argmax(v) for v in y_pred]

# %%
y_pred

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
